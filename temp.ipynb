# %%
# %pip install playwright
# %playwright install
# Out:
# Collecting playwright
#   Using cached playwright-1.58.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Using cached pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting greenlet<4.0.0,>=3.1.1 (from playwright)
#   Using cached greenlet-3.4.0-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.12/site-packages (from pyee<14,>=13->playwright) (4.15.0)
# Using cached playwright-1.58.0-py3-none-macosx_11_0_arm64.whl (41.0 MB)
# Using cached greenlet-3.4.0-cp312-cp312-macosx_11_0_universal2.whl (286 kB)
# Using cached pyee-13.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, greenlet, playwright
# Successfully installed greenlet-3.4.0 playwright-1.58.0 pyee-13.0.1
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%playwright` not found.

# %%
import asyncio
from playwright.async_api import async_playwright

async def crawl_naver():
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()
        
        await page.goto("https://m.stock.naver.com/worldstock/etf/SPY/total")
        await page.wait_for_timeout(500)
        await page.screenshot(path="naver_result.png")
        await browser.close()

await crawl_naver()
